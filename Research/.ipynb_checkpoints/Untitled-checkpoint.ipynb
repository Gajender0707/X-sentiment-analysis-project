# %%
import requests

url = "https://twitter-api45.p.rapidapi.com/timeline.php"

querystring = {"screenname":"elonmusk"}

headers = {
	"x-rapidapi-key": "6387b1d230msh29633aa0636c084p1aa086jsnccd798b3174e",
	"x-rapidapi-host": "twitter-api45.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
print(response.json())
# Out:
# {'timeline': [{'tweet_id': '1869278165639811343', 'bookmarks': 102, 'created_at': 'Wed Dec 18 07:06:58 +0000 2024', 'favorites': 7254, 'text': 'Congrats @SpaceX Falcon team!', 'lang': 'en', 'views': '825118', 'quotes': 58, 'entities': {'hashtags': [], 'symbols': [], 'timestamps': [], 'urls': [], 'user_mentions': [{'id_str': '34743251', 'name': 'SpaceX', 'screen_name': 'SpaceX'}]}, 'replies': 1289, 'retweets': 859, 'conversation_id': '1869278165639811343', 'media': [], 'author': {'rest_id': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg', 'blue_verified': True}, 'quoted': {'tweet_id': '1869221857930703078', 'bookmarks': 109, 'created_at': 'Wed Dec 18 03:23:14 +0000 2024', 'favorites': 5896, 'text': 'Teams complete three successful Falcon 9 missions in under 24 hours https://t.co/us2i2AotB1', 'lang': 'en', 'views': '1111971', 'quotes': 102, 'replies': 428, 'retweets': 756, 'conversation_id': '1869221857930703078', 'author': {'rest_id': '34743251', 'name': 'SpaceX', 'screen_name': 'SpaceX', 'avatar': 'https://pbs.twimg.com/profile_images/1697749409851985920/HbrI04tM_normal.jpg', 'blue_verified': True}, 'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfDPO-NW0AAo6Px.jpg', 'id': '1869221701482893312', 'sizes': {'h': 1200, 'w': 840}}, {'media_url_https': 'https://pbs.twimg.com/media/GfDPQ1FXUAAQc6g.jpg', 'id': '1869221733393190912', 'sizes': {'h': 554, 'w': 1200}}, {'media_url_https': 'https://pbs.twimg.com/media/GfDPVt8XIAA8nGP.jpg', 'id': '1869221817375727616', 'sizes': {'h': 554, 'w': 1200}}]}}}, {'tweet_id': '1869133454950228312', 'bookmarks': 1780, 'created_at': 'Tue Dec 17 21:31:57 +0000 2024', 'favorites': 92947, 'text': 'Guess who this is? 🤣🤣 https://t.co/XHWcgIa04W', 'lang': 'en', 'views': '13570260', 'quotes': 1599, 'replies': 18304, 'retweets': 10174, 'conversation_id': '1869133454950228312', 'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfB-9X3aIAApDN9.jpg', 'id': '1869133438202290176'}]}, 'entities': {'hashtags': [], 'symbols': [], 'timestamps': [], 'urls': [], 'user_mentions': []}}, {'tweet_id': '1869133622055407879', 'bookmarks': 174, 'created_at': 'Tue Dec 17 21:32:36 +0000 2024', 'favorites': 9752, 'text': 'Made with @Grok\nhttps://t.co/1cfbK7etiN', 'lang': 'en', 'views': '1515672', 'quotes': 52, 'replies': 1164, 'retweets': 1044, 'conversation_id': '1869133454950228312', 'media': [], 'reply_to': '1869133454950228312', 'entities': {'hashtags': [], 'symbols': [], 'timestamps': [], 'urls': [{'display_url': 'x.com/i/grok/share/W…', 'expanded_url': 'https://x.com/i/grok/share/W7gwlp1vnqIgeghCDP3nNszym', 'url': 'https://t.co/1cfbK7etiN'}], 'user_mentions': [{'id_str': '1720665183188922368', 'name': 'Grok', 'screen_name': 'grok'}]}}, {'tweet_id': '1869276881180406257', 'bookmarks': 18, 'created_at': 'Wed Dec 18 07:01:52 +0000 2024', 'favorites': 1946, 'text': '@grok Cake \nhttps://t.co/iKf47HuI8W', 'lang': 'en', 'views': '246934', 'quotes': 20, 'replies': 592, 'retweets': 166, 'conversation_id': '1869133454950228312', 'media': [], 'reply_to': '1869133622055407879', 'entities': {'hashtags': [], 'symbols': [], 'timestamps': [], 'urls': [{'display_url': 'x.com/i/grok/share/J…', 'expanded_url': 'https://x.com/i/grok/share/JGt9JWKr9DSx8nmYpHdnDoyDg', 'url': 'https://t.co/iKf47HuI8W'}], 'user_mentions': [{'id_str': '1720665183188922368', 'name': 'Grok', 'screen_name': 'grok'}]}}, {'tweet_id': '1869138229511033338', 'bookmarks': 1616, 'created_at': 'Tue Dec 17 21:50:55 +0000 2024', 'favorites': 79369, 'text': 'Yeah, this explains a lot. \n\nShame on @Reuters. \n\nPaid propaganda!', 'lang': 'en', 'views': '13480686', 'quotes': 403, 'entities': {'hashtags': [], 'symbols': [], 'timestamps': [], 'urls': [], 'user_mentions': [{'id_str': '1652541', 'name': 'Reuters', 'screen_name': 'Reuters'}]}, 'replies': 4474, 'retweets': 16239, 'conversation_id': '1869138229511033338', 'media': [], 'author ...

# %%
data=response.json()
len(data["timeline"])
# Out:
# 20

# %%
data["timeline"]
# Out:
# [{'tweet_id': '1869278165639811343',
#   'bookmarks': 87,
#   'created_at': 'Wed Dec 18 07:06:58 +0000 2024',
#   'favorites': 5434,
#   'text': 'Congrats @SpaceX Falcon team!',
#   'lang': 'en',
#   'views': '578041',
#   'quotes': 49,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': [{'id_str': '34743251',
#      'name': 'SpaceX',
#      'screen_name': 'SpaceX'}]},
#   'replies': 1140,
#   'retweets': 623,
#   'conversation_id': '1869278165639811343',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869221857930703078',
#    'bookmarks': 105,
#    'created_at': 'Wed Dec 18 03:23:14 +0000 2024',
#    'favorites': 5717,
#    'text': 'Teams complete three successful Falcon 9 missions in under 24 hours https://t.co/us2i2AotB1',
#    'lang': 'en',
#    'views': '860214',
#    'quotes': 98,
#    'replies': 404,
#    'retweets': 734,
#    'conversation_id': '1869221857930703078',
#    'author': {'rest_id': '34743251',
#     'name': 'SpaceX',
#     'screen_name': 'SpaceX',
#     'avatar': 'https://pbs.twimg.com/profile_images/1697749409851985920/HbrI04tM_normal.jpg',
#     'blue_verified': True},
#    'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfDPO-NW0AAo6Px.jpg',
#       'id': '1869221701482893312',
#       'sizes': {'h': 1200, 'w': 840}},
#      {'media_url_https': 'https://pbs.twimg.com/media/GfDPQ1FXUAAQc6g.jpg',
#       'id': '1869221733393190912',
#       'sizes': {'h': 554, 'w': 1200}},
#      {'media_url_https': 'https://pbs.twimg.com/media/GfDPVt8XIAA8nGP.jpg',
#       'id': '1869221817375727616',
#       'sizes': {'h': 554, 'w': 1200}}]}}},
#  {'tweet_id': '1869133454950228312',
#   'bookmarks': 1772,
#   'created_at': 'Tue Dec 17 21:31:57 +0000 2024',
#   'favorites': 92391,
#   'text': 'Guess who this is? 🤣🤣 https://t.co/XHWcgIa04W',
#   'lang': 'en',
#   'views': '13299801',
#   'quotes': 1591,
#   'replies': 18223,
#   'retweets': 10120,
#   'conversation_id': '1869133454950228312',
#   'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfB-9X3aIAApDN9.jpg',
#      'id': '1869133438202290176'}]},
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': []}},
#  {'tweet_id': '1869133622055407879',
#   'bookmarks': 171,
#   'created_at': 'Tue Dec 17 21:32:36 +0000 2024',
#   'favorites': 9588,
#   'text': 'Made with @Grok\nhttps://t.co/1cfbK7etiN',
#   'lang': 'en',
#   'views': '1463401',
#   'quotes': 52,
#   'replies': 1162,
#   'retweets': 1031,
#   'conversation_id': '1869133454950228312',
#   'media': [],
#   'reply_to': '1869133454950228312',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [{'display_url': 'x.com/i/grok/share/W…',
#      'expanded_url': 'https://x.com/i/grok/share/W7gwlp1vnqIgeghCDP3nNszym',
#      'url': 'https://t.co/1cfbK7etiN'}],
#    'user_mentions': [{'id_str': '1720665183188922368',
#      'name': 'Grok',
#      'screen_name': 'grok'}]}},
#  {'tweet_id': '1869276881180406257',
#   'bookmarks': 16,
#   'created_at': 'Wed Dec 18 07:01:52 +0000 2024',
#   'favorites': 1686,
#   'text': '@grok Cake \nhttps://t.co/iKf47HuI8W',
#   'lang': 'en',
#   'views': '194246',
#   'quotes': 19,
#   'replies': 550,
#   'retweets': 145,
#   'conversation_id': '1869133454950228312',
#   'media': [],
#   'reply_to': '1869133622055407879',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [{'display_url': 'x.com/i/grok/share/J…',
#      'expanded_url': 'https://x.com/i/grok/share/JGt9JWKr9DSx8nmYpHdnDoyDg',
#      'url': 'https://t.co/iKf47HuI8W'}],
#    'user_mentions': [{'id_str': '1720665183188922368',
#      'name': 'Grok',
#      'screen_name': 'grok'}]}},
#  {'tweet_id': '1869138229511033338',
#   'bookmarks': 1600,
#   'created_at': 'Tue Dec 17 21:50:55 +0000 2024',
#   'favorites': 78759,
#   'text': 'Yeah, this explains a lot. \n\nShame on @Reuters. \n\nPaid propaganda!',
#   'lang': 'en',
#   'views': '13297837',
#   'quotes': 400,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': [{'id_str': '1652541',
#      'name': 'Reuters',
#      'screen_name': 'Reuters'}]},
#   'replies': 4457,
#   'retweets': 16103,
#   'conversation_id': '1869138229511033338',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869089408210932051',
#    'bookmarks': 839,
#    'created_at': 'Tue Dec 17 18:36:55 +0000 2024',
#    'favorites': 11016,
#    'text': 'Wow. Turns out all those Reuters hit pieces were funded by the Biden administration. \n\nI remember thinking this is so weird, why is Reuters suddenly so anti-Tesla. They wanted to look cool for Biden.',
#    'lang': 'en',
#    'views': '13613277',
#    'quotes': 170,
#    'replies': 525,
#    'retweets': 2550,
#    'conversation_id': '1869089408210932051',
#    'author': {'rest_id': '1263491240336769026',
#     'name': 'Whole Mars Catalog',
#     'screen_name': 'WholeMarsBlog',
#     'avatar': 'https://pbs.twimg.com/profile_images/1593688242771017728/1Ocz0cvu_normal.jpg',
#     'blue_verified': True},
#    'media': []}},
#  {'tweet_id': '1869137211800862900',
#   'bookmarks': 1852,
#   'created_at': 'Tue Dec 17 21:46:52 +0000 2024',
#   'favorites': 118776,
#   'text': 'Free your friends from the sadness generating propaganda machine that is legacy media and get them on 𝕏 so they know what’s really happening!',
#   'lang': 'en',
#   'views': '21169804',
#   'quotes': 1032,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': []},
#   'replies': 8089,
#   'retweets': 14791,
#   'conversation_id': '1869137211800862900',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True}},
#  {'tweet_id': '1869132892540121453',
#   'bookmarks': 518,
#   'created_at': 'Tue Dec 17 21:29:43 +0000 2024',
#   'favorites': 47910,
#   'text': 'True',
#   'lang': 'en',
#   'views': '5375214',
#   'quotes': 135,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': []},
#   'replies': 1597,
#   'retweets': 9160,
#   'conversation_id': '1869132892540121453',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869095749268754680',
#    'bookmarks': 127,
#    'created_at': 'Tue Dec 17 19:02:07 +0000 2024',
#    'favorites': 5641,
#    'text': 'The Washington Post is more offended that Trump hilariously calls Elizabeth Warren “Pocahontas” than they are that she used her fake heritage to get ahead in life.\n\nYou don’t hate legacy media enough. https://t.co/no0rzuFwnk',
#    'lang': 'en',
#    'views': '5479613',
#    'quotes': 74,
#    'replies': 266,
#    'retweets': 1183,
#    'conversation_id': '1869095749268754680',
#    'author': {'rest_id': '534023',
#     'name': 'ALX 🇺🇸',
#     'screen_name': 'alx',
#     'avatar': 'https://pbs.twimg.com/profile_images/1820708761406775296/J12pbn0e_normal.jpg',
#     'blue_verified': True},
#    'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfBcrOpWYAAYRfk.jpg',
#       'id': '1869095743094415360',
#       'sizes': {'h': 1200, 'w': 960}}]}}},
#  {'tweet_id': '1869132090857632158',
#   'bookmarks': 670,
#   'created_at': 'Tue Dec 17 21:26:31 +0000 2024',
#   'favorites': 69124,
#   'text': 'This is the way',
#   'lang': 'en',
#   'views': '8094555',
#   'quotes': 179,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': []},
#   'replies': 2411,
#   'retweets': 8039,
#   'conversation_id': '1869132090857632158',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869102650102550638',
#    'bookmarks': 386,
#    'created_at': 'Tue Dec 17 19:29:32 +0000 2024',
#    'favorites': 38034,
#    'text': "I believe that it’s appropriate and the responsibility of a U.S. Senator to have a conversation with President-elect Trump's nominees. \n\nThat’s why I met with Elise Stefanik and Pete Hegseth, just wrapped with Tulsi Gabbard, and look forward to my meetings with others soon.\n\nMy https://t.co/Vli5tr8XSr",
#    'lang': 'en',
#    'views': '9102848',
#    'quotes': 459,
#    'replies': 2942,
#    'retweets': 3194,
#    'conversation_id': '1869102650102550638',
#    'author': {'rest_id': '1612264272364453888',
#     'name': 'U.S. Senator John Fetterman',
#     'screen_name': 'SenFettermanPA',
#     'avatar': 'https://pbs.twimg.com/profile_images/1856434808886325248/2tOaQ4QE_normal.jpg',
#     'blue_verified': True},
#    'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfBi9FDWUAA22jj.jpg',
#       'id': '1869102646826520576',
#       'sizes': {'h': 1200, 'w': 1052}}]}}},
#  {'tweet_id': '1869127968972554728',
#   'bookmarks': 2898,
#   'created_at': 'Tue Dec 17 21:10:09 +0000 2024',
#   'favorites': 61983,
#   'text': 'Path of Exile 2, Arbiter of Ash.\n\nPlayed over @Starlink in an airplane.\n\nStarlink is so good that you can play real-time video games while airborne! https://t.co/DEpRJYfU6y',
#   'lang': 'en',
#   'views': '16842488',
#   'quotes': 423,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': [{'id_str': '1330170106501079041',
#      'name': 'Starlink',
#      'screen_name': 'Starlink'}]},
#   'replies': 3205,
#   'retweets': 4781,
#   'conversation_id': '1869127968972554728',
#   'media': {'video': [{'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1869125753058549760/pu/img/y0eq0_ypXOMmJx5m.jpg',
#      'variants': [{'content_type': 'application/x-mpegURL',
#        'url': 'https://video.twimg.com/ext_tw_video/1869125753058549760/pu/pl/uyz829gjF7rJe6-1.m3u8?tag=14&v=a7e'},
#       {'bitrate': 256000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1869125753058549760/pu/vid/avc1/480x270/07SV3962tU1DN6En.mp4?tag=14'},
#       {'bitrate': 832000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1869125753058549760/pu/vid/avc1/640x360/IUhWv1GH-bU8wR_w.mp4?tag=14'},
#       {'bitrate': 2176000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1869125753058549760/pu/vid/avc1/1280x720/cJVtY3fZ4nILaW1Y.mp4?tag=14'},
#       {'bitrate': 10368000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1869125753058549760/pu/vid/avc1/1920x1080/61ku4VUFx_7j5XMb.mp4?tag=14'}],
#      'aspect_ratio': [16, 9],
#      'original_info': {'height': 1080, 'width': 1920, 'focus_rects': []},
#      'id': '1869125753058549760'}]},
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True}},
#  {'tweet_id': '1869127380838777134',
#   'bookmarks': 372,
#   'created_at': 'Tue Dec 17 21:07:48 +0000 2024',
#   'favorites': 12964,
#   'text': 'Grok can explain almost anything!',
#   'lang': 'en',
#   'views': '5828143',
#   'quotes': 116,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': []},
#   'replies': 2257,
#   'retweets': 1936,
#   'conversation_id': '1869127380838777134',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869126873713893615',
#    'bookmarks': 63,
#    'created_at': 'Tue Dec 17 21:05:48 +0000 2024',
#    'favorites': 697,
#    'text': '"Grok explain" is helping me understand how not spilling coffee while walking relates to rocket stability 😅 https://t.co/C98T3FnSQQ',
#    'lang': 'en',
#    'views': '5868078',
#    'quotes': 20,
#    'replies': 97,
#    'retweets': 53,
#    'conversation_id': '1869126873713893615',
#    'author': {'rest_id': '956329237',
#     'name': 'Luis Batalha 🇵🇹🇺🇸',
#     'screen_name': 'luismbat',
#     'avatar': 'https://pbs.twimg.com/profile_images/378800000564279654/544464e51ec3be835a561a7f631379ab_normal.png',
#     'blue_verified': True},
#    'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfB36O6XUAAqmbD.jpg',
#       'id': '1869125687677767680',
#       'sizes': {'h': 815, 'w': 1200}}]}}},
#  {'tweet_id': '1869119942685327503',
#   'bookmarks': 660,
#   'created_at': 'Tue Dec 17 20:38:15 +0000 2024',
#   'favorites': 31824,
#   'text': 'Yes, we added the ability to zoom in and rewind to live streams',
#   'lang': 'en',
#   'views': '8927813',
#   'quotes': 173,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': []},
#   'replies': 2481,
#   'retweets': 2952,
#   'conversation_id': '1869119942685327503',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869118029831008543',
#    'bookmarks': 38,
#    'created_at': 'Tue Dec 17 20:30:39 +0000 2024',
#    'favorites': 679,
#    'text': '@elonmusk I can zoom in on it even though it’s live, is that new? That’s epic. https://t.co/YDDF4lRd7e',
#    'lang': 'en',
#    'views': '8977041',
#    'quotes': 28,
#    'replies': 121,
#    'retweets': 56,
#    'conversation_id': '1869117106794762705',
#    'author': {'rest_id': '1233929232432205827',
#     'name': 'Gail Alfar',
#     'screen_name': 'GailAlfarATX',
#     'avatar': 'https://pbs.twimg.com/profile_images/1862025904660058112/YHci7E9O_normal.jpg',
#     'blue_verified': True},
#    'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfBw8MeWMAAIDJF.jpg',
#       'id': '1869118024801726464',
#       'sizes': {'h': 1200, 'w': 607}}]}}},
#  {'tweet_id': '1869117106794762705',
#   'bookmarks': 1409,
#   'created_at': 'Tue Dec 17 20:26:59 +0000 2024',
#   'favorites': 46457,
#   'text': 'Testing streaming on X via Starlink https://t.co/91ilYMadda',
#   'lang': 'en',
#   'views': '11182161',
#   'quotes': 440,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [{'display_url': 'x.com/i/broadcasts/1…',
#      'expanded_url': 'https://x.com/i/broadcasts/1gqxvNEaykgxB',
#      'url': 'https://t.co/91ilYMadda'}],
#    'user_mentions': []},
#   'replies': 4601,
#   'retweets': 5666,
#   'conversation_id': '1869117106794762705',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True}},
#  {'tweet_id': '1869105846229389424',
#   'bookmarks': 310,
#   'created_at': 'Tue Dec 17 19:42:14 +0000 2024',
#   'favorites': 39293,
#   'text': '💯 \n\n@PamBondi is awesome',
#   'lang': 'en',
#   'views': '13809456',
#   'quotes': 106,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': [{'id_str': '93755660',
#      'name': 'Pam Bondi',
#      'screen_name': 'PamBondi'}]},
#   'replies': 1878,
#   'retweets': 5110,
#   'conversation_id': '1869105846229389424',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1868993295193645254',
#    'bookmarks': 98,
#    'created_at': 'Tue Dec 17 12:15:00 +0000 2024',
#    'favorites': 11398,
#    'text': 'No one will do a better job draining the swamp at the Department of Justice than @PamBondi 🇺🇸🇺🇸🇺🇸\n\nWashington Examiner: Trump’s DOJ cleaning crew will sweep up cronyism\n\nhttps://t.co/rmuyD0INqE',
#    'lang': 'en',
#    'views': '14003472',
#    'quotes': 76,
#    'replies': 869,
#    'retweets': 1695,
#    'conversation_id': '1868993295193645254',
#    'author': {'rest_id': '39344374',
#     'name': 'Donald Trump Jr.',
#     'screen_name': 'DonaldJTrumpJr',
#     'avatar': 'https://pbs.twimg.com/profile_images/766652495858896897/LjrJJB9a_normal.jpg',
#     'blue_verified': True},
#    'media': []}},
#  {'tweet_id': '1869104841483800636',
#   'bookmarks': 701,
#   'created_at': 'Tue Dec 17 19:38:15 +0000 2024',
#   'favorites': 81884,
#   'text': 'Support @TulsiGabbard for DNI!',
#   'lang': 'en',
#   'views': '26583169',
#   'quotes': 247,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': [{'id_str': '26637348',
#      'name': 'Tulsi Gabbard 🌺',
#      'screen_name': 'TulsiGabbard'}]},
#   'replies': 2252,
#   'retweets': 9917,
#   'conversation_id': '1869104841483800636',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869096230317638112',
#    'bookmarks': 431,
#    'created_at': 'Tue Dec 17 19:04:02 +0000 2024',
#    'favorites': 43996,
#    'text': 'I am truly honored and humbled.',
#    'lang': 'en',
#    'views': '27048278',
#    'quotes': 173,
#    'replies': 1391,
#    'retweets': 5729,
#    'conversation_id': '1869096230317638112',
#    'author': {'rest_id': '26637348',
#     'name': 'Tulsi Gabbard 🌺',
#     'screen_name': 'TulsiGabbard',
#     'avatar': 'https://pbs.twimg.com/profile_images/1786183993475399680/gdJaqmsJ_normal.jpg',
#     'blue_verified': True},
#    'media': []}},
#  {'tweet_id': '1869103980149973204',
#   'bookmarks': 2166,
#   'created_at': 'Tue Dec 17 19:34:49 +0000 2024',
#   'favorites': 65676,
#   'text': 'Lmao. \n\nThe person actually writing these things from Pocahontas are SBF’s parents btw.',
#   'lang': 'en',
#   'views': '9238116',
#   'quotes': 470,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': []},
#   'replies': 3080,
#   'retweets': 10113,
#   'conversation_id': '1869103980149973204',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869102856181330248',
#    'bookmarks': 271,
#    'created_at': 'Tue Dec 17 19:30:21 +0000 2024',
#    'favorites': 8527,
#    'text': 'Holy mother of based!!! 🔥🔥🔥🔥 https://t.co/Q7P2oPBXZB',
#    'lang': 'en',
#    'views': '9610112',
#    'quotes': 160,
#    'replies': 302,
#    'retweets': 1200,
#    'conversation_id': '1869102856181330248',
#    'author': {'rest_id': '294293982',
#     'name': 'Rothmus 🏴',
#     'screen_name': 'Rothmus',
#     'avatar': 'https://pbs.twimg.com/profile_images/1427434033290661891/hLTTZ5lt_normal.jpg',
#     'blue_verified': True},
#    'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfBjJCaXMAAJ1qP.jpg',
#       'id': '1869102852276170752',
#       'sizes': {'h': 1105, 'w': 1179}}]}}},
#  {'tweet_id': '1869103027417940475',
#   'bookmarks': 0,
#   'created_at': 'Tue Dec 17 19:31:02 +0000 2024',
#   'favorites': 0,
#   'text': 'RT @thatsKAIZEN: Criticizing the Israeli government doesn’t make you an Antisemite\n\nCriticizing Hamas doesn’t make you an Islamophobe\n\nCrit…',
#   'lang': 'en',
#   'views': '26',
#   'quotes': 0,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': [{'id_str': '282419632',
#      'name': 'Kaizen D. Asiedu',
#      'screen_name': 'thatsKAIZEN'}]},
#   'replies': 0,
#   'retweets': 2153,
#   'conversation_id': '1869103027417940475',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'retweeted': {'id': '1869095256253456573'},
#   'retweeted_tweet': {'tweet_id': '1869095256253456573',
#    'bookmarks': 509,
#    'created_at': 'Tue Dec 17 19:00:09 +0000 2024',
#    'favorites': 12632,
#    'text': 'Criticizing the Israeli government doesn’t make you an Antisemite\n\nCriticizing Hamas doesn’t make you an Islamophobe\n\nCriticizing BLM doesn’t make you a racist\n\nCriticizing child sex surgery doesn’t make you a homophobe\n\nCriticizing vaccine mandates doesn’t make you anti-vaxx',
#    'lang': 'en',
#    'views': '1065727',
#    'quotes': 145,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'replies': 649,
#    'retweets': 2153,
#    'conversation_id': '1869095256253456573',
#    'author': {'rest_id': '282419632',
#     'name': 'Kaizen D. Asiedu',
#     'screen_name': 'thatsKAIZEN',
#     'avatar': 'https://pbs.twimg.com/profile_images/1861997595264176128/kwXTA0xm_normal.jpg',
#     'blue_verified': True},
#    'media': []}},
#  {'tweet_id': '1869087700449677339',
#   'bookmarks': 2630,
#   'created_at': 'Tue Dec 17 18:30:08 +0000 2024',
#   'favorites': 52083,
#   'text': 'Bubble needs to be popped',
#   'lang': 'en',
#   'views': '11989977',
#   'quotes': 352,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': []},
#   'replies': 4370,
#   'retweets': 7932,
#   'conversation_id': '1869087700449677339',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869087140132614300',
#    'bookmarks': 671,
#    'created_at': 'Tue Dec 17 18:27:54 +0000 2024',
#    'favorites': 3928,
#    'text': 'Academia is a Woke Bubble https://t.co/PZe9TSPXzN',
#    'lang': 'en',
#    'views': '12097267',
#    'quotes': 282,
#    'replies': 576,
#    'retweets': 875,
#    'conversation_id': '1869087140132614300',
#    'author': {'rest_id': '1485689970593468416',
#     'name': 'The Rabbit Hole',
#     'screen_name': 'TheRabbitHole84',
#     'avatar': 'https://pbs.twimg.com/profile_images/1522017422550528001/6AceRKJQ_normal.png',
#     'blue_verified': True},
#    'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfBU2QVagAAY3eI.jpg',
#       'id': '1869087136433209344',
#       'sizes': {'h': 875, 'w': 902}}]}}},
#  {'tweet_id': '1869086943042269629',
#   'bookmarks': 533,
#   'created_at': 'Tue Dec 17 18:27:07 +0000 2024',
#   'favorites': 34423,
#   'text': 'Yes, this is how all company and country leaders should use 𝕏!\n\nDirect communication is the best way to get your message to the public, without having to go through the legacy media negativity filter.',
#   'lang': 'en',
#   'views': '11264162',
#   'quotes': 132,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': []},
#   'replies': 1798,
#   'retweets': 3975,
#   'conversation_id': '1869086943042269629',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869084895471177931',
#    'bookmarks': 50,
#    'created_at': 'Tue Dec 17 18:18:59 +0000 2024',
#    'favorites': 2573,
#    'text': 'Very happy to see @sundarpichai is personally active on 𝕏 and engaging as a regular user, not via his “media / comm manager or office”.',
#    'lang': 'en',
#    'views': '11320030',
#    'quotes': 21,
#    'replies': 115,
#    'retweets': 148,
#    'conversation_id': '1869084895471177931',
#    'author': {'rest_id': '431777800',
#     'name': 'حسن سجواني 🇦🇪 Hassan Sajwani',
#     'screen_name': 'HSajwanization',
#     'avatar': 'https://pbs.twimg.com/profile_images/1525434442021539842/99GMvtNA_normal.jpg',
#     'blue_verified': True},
#    'media': []}},
#  {'tweet_id': '1869086065853902968',
#   'bookmarks': 393,
#   'created_at': 'Tue Dec 17 18:23:38 +0000 2024',
#   'favorites': 23141,
#   'text': 'Testing Raptoe rocket engine restart for orbit changes',
#   'lang': 'en',
#   'views': '7242364',
#   'quotes': 132,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': []},
#   'replies': 1740,
#   'retweets': 3408,
#   'conversation_id': '1869086065853902968',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869080468160995439',
#    'bookmarks': 461,
#    'created_at': 'Tue Dec 17 18:01:24 +0000 2024',
#    'favorites': 9256,
#    'text': 'Single engine static fire demonstrating a flight-like startup for an in-space burn https://t.co/jELpcCOaO5',
#    'lang': 'en',
#    'views': '7590180',
#    'quotes': 160,
#    'replies': 486,
#    'retweets': 1321,
#    'conversation_id': '1869080468160995439',
#    'author': {'rest_id': '34743251',
#     'name': 'SpaceX',
#     'screen_name': 'SpaceX',
#     'avatar': 'https://pbs.twimg.com/profile_images/1697749409851985920/HbrI04tM_normal.jpg',
#     'blue_verified': True},
#    'media': {'video': [{'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1869080224404803584/pu/img/JdMni2fgGkZK1qWM.jpg',
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1869080224404803584/pu/pl/xWL1oi1W-qwVxqJn.m3u8?tag=14&v=cfc'},
#        {'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1869080224404803584/pu/vid/avc1/480x270/NWmELeZpABpfSuAR.mp4?tag=14'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1869080224404803584/pu/vid/avc1/640x360/nKgdoZ9v57Wjijn1.mp4?tag=14'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1869080224404803584/pu/vid/avc1/1280x720/pdC0SMvdgndHZDWQ.mp4?tag=14'},
#        {'bitrate': 10368000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1869080224404803584/pu/vid/avc1/1920x1080/H6WbcIQIqKHr5Bwl.mp4?tag=14'}],
#       'aspect_ratio': [16, 9],
#       'original_info': {'height': 1080, 'width': 1920, 'focus_rects': []},
#       'id': '1869080224404803584'},
#      {'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1869080379585687552/pu/img/Rqz49dHiM4B73bfx.jpg',
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1869080379585687552/pu/pl/86XTqo3-Q_q15vjL.m3u8?tag=14&v=cfc'},
#        {'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1869080379585687552/pu/vid/avc1/480x270/JpptpcPjjUX7R9qi.mp4?tag=14'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1869080379585687552/pu/vid/avc1/640x360/OUs2WRv7J4UWTNY8.mp4?tag=14'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1869080379585687552/pu/vid/avc1/1280x720/Xe4rt89hNJHDYlfy.mp4?tag=14'},
#        {'bitrate': 10368000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1869080379585687552/pu/vid/avc1/1920x1080/d-mG1zRZc2C5-WEM.mp4?tag=14'}],
#       'aspect_ratio': [16, 9],
#       'original_info': {'height': 1080, 'width': 1920, 'focus_rects': []},
#       'id': '1869080379585687552'}],
#     'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfBOpTOakAA9dte.jpg',
#       'id': '1869080316801093632',
#       'sizes': {'h': 1200, 'w': 800}},
#      {'media_url_https': 'https://pbs.twimg.com/media/GfBOsDKbsAA1f8I.jpg',
#       'id': '1869080364029030400',
#       'sizes': {'h': 675, 'w': 1200}}]}}},
#  {'tweet_id': '1869071514043318534',
#   'bookmarks': 3772,
#   'created_at': 'Tue Dec 17 17:25:49 +0000 2024',
#   'favorites': 80442,
#   'text': '🤨',
#   'lang': 'art',
#   'views': '7775186',
#   'quotes': 963,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'timestamps': [],
#    'urls': [],
#    'user_mentions': []},
#   'replies': 6665,
#   'retweets': 26106,
#   'conversation_id': '1869071514043318534',
#   'media': [],
#   'author': {'rest_id': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'avatar': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#    'blue_verified': True},
#   'quoted': {'tweet_id': '1869071208811000195',
#    'bookmarks': 1013,
#    'created_at': 'Tue Dec 17 17:24:36 +0000 2024',
#    'favorites': 8737,
#    'text': "WEAPONIZATION: Biden publicly ordered 11 federal agencies to 'look' into Elon Musk. All 11 opened investigations. Then all 11 funneled a total of $300M to Reuters who then who won a Pulitzer Prize for their relentless attack pieces against the billionaire.\n\nh/t @MikeBenzCyber https://t.co/BaloKPx8G4",
#    'lang': 'en',
#    'views': '8052581',
#    'quotes': 428,
#    'replies': 841,
#    'retweets': 3535,
#    'conversation_id': '1869071208811000195',
#    'author': {'rest_id': '4239551',
#     'name': '@amuse',
#     'screen_name': 'amuse',
#     'avatar': 'https://pbs.twimg.com/profile_images/1621897638328008709/qK4vDITA_normal.jpg',
#     'blue_verified': True},
#    'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfBF3SvWkAAIReQ.jpg',
#       'id': '1869070661584326656',
#       'sizes': {'h': 1200, 'w': 1200}}]}}}]

# %%
import pandas as pd

# %%
data=pd.DataFrame(data["timeline"])

# %%
data.head()
# Out:
#               tweet_id  bookmarks                      created_at  favorites  \
# 0  1869278165639811343         87  Wed Dec 18 07:06:58 +0000 2024       5434
# 1  1869133454950228312       1772  Tue Dec 17 21:31:57 +0000 2024      92391
# 2  1869133622055407879        171  Tue Dec 17 21:32:36 +0000 2024       9588
# 3  1869276881180406257         16  Wed Dec 18 07:01:52 +0000 2024       1686
# 4  1869138229511033338       1600  Tue Dec 17 21:50:55 +0000 2024      78759
#
#                                                 text lang     views  quotes  \
# 0                      Congrats @SpaceX Falcon team!   en    578041      49
# 1      Guess who this is? 🤣🤣 https://t.co/XHWcgIa04W   en  13299801    1591
# 2           Made with @Grok\nhttps://t.co/1cfbK7etiN   en   1463401      52
# 3               @grok Cake \nhttps://t.co/iKf47HuI8W   en    194246      19
# 4  Yeah, this explains a lot. \n\nShame on @Reute...   en  13297837     400
#
#                                             entities  replies  retweets  \
# 0  {'hashtags': [], 'symbols': [], 'timestamps': ...     1140       623
# 1  {'hashtags': [], 'symbols': [], 'timestamps': ...    18223     10120
# 2  {'hashtags': [], 'symbols': [], 'timestamps': ...     1162      1031
# 3  {'hashtags': [], 'symbols': [], 'timestamps': ...      550       145
# 4  {'hashtags': [], 'symbols': [], 'timestamps': ...     4457     16103
#
#        conversation_id                                              media  \
# 0  1869278165639811343                                                 []
# 1  1869133454950228312  {'photo': [{'media_url_https': 'https://pbs.tw...
# 2  1869133454950228312                                                 []
# 3  1869133454950228312                                                 []
# 4  1869138229511033338                                                 []
#
#                                               author  \
# 0  {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'rest_id': '44196397', 'name': 'Elon Musk', '...
#
#                                               quoted             reply_to  \
# 0  {'tweet_id': '1869221857930703078', 'bookmarks...                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN  1869133454950228312
# 3                                                NaN  1869133622055407879
# 4  {'tweet_id': '1869089408210932051', 'bookmarks...                  NaN
#
#   retweeted retweeted_tweet
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3       NaN             NaN
# 4       NaN             NaN

# %%
data.shape
# Out:
# (20, 18)

# %%
data
# Out:
#                tweet_id  bookmarks                      created_at  favorites  \
# 0   1869278165639811343         87  Wed Dec 18 07:06:58 +0000 2024       5434
# 1   1869133454950228312       1772  Tue Dec 17 21:31:57 +0000 2024      92391
# 2   1869133622055407879        171  Tue Dec 17 21:32:36 +0000 2024       9588
# 3   1869276881180406257         16  Wed Dec 18 07:01:52 +0000 2024       1686
# 4   1869138229511033338       1600  Tue Dec 17 21:50:55 +0000 2024      78759
# 5   1869137211800862900       1852  Tue Dec 17 21:46:52 +0000 2024     118776
# 6   1869132892540121453        518  Tue Dec 17 21:29:43 +0000 2024      47910
# 7   1869132090857632158        670  Tue Dec 17 21:26:31 +0000 2024      69124
# 8   1869127968972554728       2898  Tue Dec 17 21:10:09 +0000 2024      61983
# 9   1869127380838777134        372  Tue Dec 17 21:07:48 +0000 2024      12964
# 10  1869119942685327503        660  Tue Dec 17 20:38:15 +0000 2024      31824
# 11  1869117106794762705       1409  Tue Dec 17 20:26:59 +0000 2024      46457
# 12  1869105846229389424        310  Tue Dec 17 19:42:14 +0000 2024      39293
# 13  1869104841483800636        701  Tue Dec 17 19:38:15 +0000 2024      81884
# 14  1869103980149973204       2166  Tue Dec 17 19:34:49 +0000 2024      65676
# 15  1869103027417940475          0  Tue Dec 17 19:31:02 +0000 2024          0
# 16  1869087700449677339       2630  Tue Dec 17 18:30:08 +0000 2024      52083
# 17  1869086943042269629        533  Tue Dec 17 18:27:07 +0000 2024      34423
# 18  1869086065853902968        393  Tue Dec 17 18:23:38 +0000 2024      23141
# 19  1869071514043318534       3772  Tue Dec 17 17:25:49 +0000 2024      80442
#
#                                                  text lang     views  quotes  \
# 0                       Congrats @SpaceX Falcon team!   en    578041      49
# 1       Guess who this is? 🤣🤣 https://t.co/XHWcgIa04W   en  13299801    1591
# 2            Made with @Grok\nhttps://t.co/1cfbK7etiN   en   1463401      52
# 3                @grok Cake \nhttps://t.co/iKf47HuI8W   en    194246      19
# 4   Yeah, this explains a lot. \n\nShame on @Reute...   en  13297837     400
# 5   Free your friends from the sadness generating ...   en  21169804    1032
# 6                                                True   en   5375214     135
# 7                                     This is the way   en   8094555     179
# 8   Path of Exile 2, Arbiter of Ash.\n\nPlayed ove...   en  16842488     423
# 9                   Grok can explain almost anything!   en   5828143     116
# 10  Yes, we added the ability to zoom in and rewin...   en   8927813     173
# 11  Testing streaming on X via Starlink https://t....   en  11182161     440
# 12                         💯 \n\n@PamBondi is awesome   en  13809456     106
# 13                     Support @TulsiGabbard for DNI!   en  26583169     247
# 14  Lmao. \n\nThe person actually writing these th...   en   9238116     470
# 15  RT @thatsKAIZEN: Criticizing the Israeli gover...   en        26       0
# 16                          Bubble needs to be popped   en  11989977     352
# 17  Yes, this is how all company and country leade...   en  11264162     132
# 18  Testing Raptoe rocket engine restart for orbit...   en   7242364     132
# 19                                                  🤨  art   7775186     963
#
#                                              entities  replies  retweets  \
# 0   {'hashtags': [], 'symbols': [], 'timestamps': ...     1140       623
# 1   {'hashtags': [], 'symbols': [], 'timestamps': ...    18223     10120
# 2   {'hashtags': [], 'symbols': [], 'timestamps': ...     1162      1031
# 3   {'hashtags': [], 'symbols': [], 'timestamps': ...      550       145
# 4   {'hashtags': [], 'symbols': [], 'timestamps': ...     4457     16103
# 5   {'hashtags': [], 'symbols': [], 'timestamps': ...     8089     14791
# 6   {'hashtags': [], 'symbols': [], 'timestamps': ...     1597      9160
# 7   {'hashtags': [], 'symbols': [], 'timestamps': ...     2411      8039
# 8   {'hashtags': [], 'symbols': [], 'timestamps': ...     3205      4781
# 9   {'hashtags': [], 'symbols': [], 'timestamps': ...     2257      1936
# 10  {'hashtags': [], 'symbols': [], 'timestamps': ...     2481      2952
# 11  {'hashtags': [], 'symbols': [], 'timestamps': ...     4601      5666
# 12  {'hashtags': [], 'symbols': [], 'timestamps': ...     1878      5110
# 13  {'hashtags': [], 'symbols': [], 'timestamps': ...     2252      9917
# 14  {'hashtags': [], 'symbols': [], 'timestamps': ...     3080     10113
# 15  {'hashtags': [], 'symbols': [], 'timestamps': ...        0      2153
# 16  {'hashtags': [], 'symbols': [], 'timestamps': ...     4370      7932
# 17  {'hashtags': [], 'symbols': [], 'timestamps': ...     1798      3975
# 18  {'hashtags': [], 'symbols': [], 'timestamps': ...     1740      3408
# 19  {'hashtags': [], 'symbols': [], 'timestamps': ...     6665     26106
#
#         conversation_id                                              media  \
# 0   1869278165639811343                                                 []
# 1   1869133454950228312  {'photo': [{'media_url_https': 'https://pbs.tw...
# 2   1869133454950228312                                                 []
# 3   1869133454950228312                                                 []
# 4   1869138229511033338                                                 []
# 5   1869137211800862900                                                 []
# 6   1869132892540121453                                                 []
# 7   1869132090857632158                                                 []
# 8   1869127968972554728  {'video': [{'media_url_https': 'https://pbs.tw...
# 9   1869127380838777134                                                 []
# 10  1869119942685327503                                                 []
# 11  1869117106794762705                                                 []
# 12  1869105846229389424                                                 []
# 13  1869104841483800636                                                 []
# 14  1869103980149973204                                                 []
# 15  1869103027417940475                                                 []
# 16  1869087700449677339                                                 []
# 17  1869086943042269629                                                 []
# 18  1869086065853902968                                                 []
# 19  1869071514043318534                                                 []
#
#                                                author  \
# 0   {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 5   {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 6   {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 7   {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 8   {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 9   {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 10  {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 11  {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 12  {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 13  {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 14  {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 15  {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 16  {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 17  {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 18  {'rest_id': '44196397', 'name': 'Elon Musk', '...
# 19  {'rest_id': '44196397', 'name': 'Elon Musk', '...
#
#                                                quoted             reply_to  \
# 0   {'tweet_id': '1869221857930703078', 'bookmarks...                  NaN
# 1                                                 NaN                  NaN
# 2                                                 NaN  1869133454950228312
# 3                                                 NaN  1869133622055407879
# 4   {'tweet_id': '1869089408210932051', 'bookmarks...                  NaN
# 5                                                 NaN                  NaN
# 6   {'tweet_id': '1869095749268754680', 'bookmarks...                  NaN
# 7   {'tweet_id': '1869102650102550638', 'bookmarks...                  NaN
# 8                                                 NaN                  NaN
# 9   {'tweet_id': '1869126873713893615', 'bookmarks...                  NaN
# 10  {'tweet_id': '1869118029831008543', 'bookmarks...                  NaN
# 11                                                NaN                  NaN
# 12  {'tweet_id': '1868993295193645254', 'bookmarks...                  NaN
# 13  {'tweet_id': '1869096230317638112', 'bookmarks...                  NaN
# 14  {'tweet_id': '1869102856181330248', 'bookmarks...                  NaN
# 15                                                NaN                  NaN
# 16  {'tweet_id': '1869087140132614300', 'bookmarks...                  NaN
# 17  {'tweet_id': '1869084895471177931', 'bookmarks...                  NaN
# 18  {'tweet_id': '1869080468160995439', 'bookmarks...                  NaN
# 19  {'tweet_id': '1869071208811000195', 'bookmarks...                  NaN
#
#                         retweeted  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15  {'id': '1869095256253456573'}
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                            NaN
#
#                                       retweeted_tweet
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'tweet_id': '1869095256253456573', 'bookmarks...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN

# %%
data["entities"]
# Out:
# 0     {'hashtags': [], 'symbols': [], 'timestamps': ...
# 1     {'hashtags': [], 'symbols': [], 'timestamps': ...
# 2     {'hashtags': [], 'symbols': [], 'timestamps': ...
# 3     {'hashtags': [], 'symbols': [], 'timestamps': ...
# 4     {'hashtags': [], 'symbols': [], 'timestamps': ...
# 5     {'hashtags': [], 'symbols': [], 'timestamps': ...
# 6     {'hashtags': [], 'symbols': [], 'timestamps': ...
# 7     {'hashtags': [], 'symbols': [], 'timestamps': ...
# 8     {'hashtags': [], 'symbols': [], 'timestamps': ...
# 9     {'hashtags': [], 'symbols': [], 'timestamps': ...
# 10    {'hashtags': [], 'symbols': [], 'timestamps': ...
# 11    {'hashtags': [], 'symbols': [], 'timestamps': ...
# 12    {'hashtags': [], 'symbols': [], 'timestamps': ...
# 13    {'hashtags': [], 'symbols': [], 'timestamps': ...
# 14    {'hashtags': [], 'symbols': [], 'timestamps': ...
# 15    {'hashtags': [], 'symbols': [], 'timestamps': ...
# 16    {'hashtags': [], 'symbols': [], 'timestamps': ...
# 17    {'hashtags': [], 'symbols': [], 'timestamps': ...
# 18    {'hashtags': [], 'symbols': [], 'timestamps': ...
# 19    {'hashtags': [], 'symbols': [], 'timestamps': ...
# Name: entities, dtype: object

# %%
import requests

url = "https://twitter-api45.p.rapidapi.com/tweet.php"

querystring = {"id":"1869278165639811343"}

headers = {
	"x-rapidapi-key": "6387b1d230msh29633aa0636c084p1aa086jsnccd798b3174e",
	"x-rapidapi-host": "twitter-api45.p.rapidapi.com"
}

response2 = requests.get(url, headers=headers, params=querystring)

data2=response2.json()
data2
# Out:
# {'likes': 8034,
#  'created_at': 'Wed Dec 18 07:06:58 +0000 2024',
#  'status': 'active',
#  'text': 'Congrats @SpaceX Falcon team!',
#  'display_text': 'Congrats @SpaceX Falcon team!',
#  'urls': [],
#  'retweets': 953,
#  'bookmarks': 113,
#  'quotes': 52,
#  'reply_to': None,
#  'replies': 1366,
#  'lang': 'en',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id_str': None,
#  'sensitive': None,
#  'views': '925720',
#  'conversation_id': '1869278165639811343',
#  'entities': {'user_mentions': [{'id_str': '34743251',
#     'name': 'SpaceX',
#     'screen_name': 'SpaceX',
#     'indices': [9, 16]}],
#   'urls': [],
#   'hashtags': [],
#   'symbols': []},
#  'author': {'rest_id': '44196397',
#   'name': 'Elon Musk',
#   'screen_name': 'elonmusk',
#   'image': 'https://pbs.twimg.com/profile_images/1858316737780781056/kPL61o0F_normal.jpg',
#   'blue_verified': True,
#   'sub_count': 207673606},
#  'media': None,
#  'quoted': {'tweet_id': '1869221857930703078',
#   'bookmarks': 112,
#   'created_at': 'Wed Dec 18 03:23:14 +0000 2024',
#   'favorites': 5975,
#   'text': 'Teams complete three successful Falcon 9 missions in under 24 hours https://t.co/us2i2AotB1',
#   'lang': 'en',
#   'views': '1216293',
#   'quotes': 95,
#   'replies': 434,
#   'retweets': 762,
#   'conversation_id': '1869221857930703078',
#   'author': {'rest_id': '34743251',
#    'name': 'SpaceX',
#    'screen_name': 'SpaceX',
#    'avatar': 'https://pbs.twimg.com/profile_images/1697749409851985920/HbrI04tM_normal.jpg',
#    'blue_verified': True},
#   'media': {'photo': [{'media_url_https': 'https://pbs.twimg.com/media/GfDPO-NW0AAo6Px.jpg',
#      'id': '1869221701482893312'},
#     {'media_url_https': 'https://pbs.twimg.com/media/GfDPQ1FXUAAQc6g.jpg',
#      'id': '1869221733393190912'},
#     {'media_url_https': 'https://pbs.twimg.com/media/GfDPVt8XIAA8nGP.jpg',
#      'id': '1869221817375727616'}]}},
#  'id': '1869278165639811343'}

# %%
type(data2)
# Out:
# dict

# %%
data2.keys()
# Out:
# dict_keys(['likes', 'created_at', 'status', 'text', 'display_text', 'urls', 'retweets', 'bookmarks', 'quotes', 'reply_to', 'replies', 'lang', 'in_reply_to_screen_name', 'in_reply_to_status_id_str', 'in_reply_to_user_id_str', 'sensitive', 'views', 'conversation_id', 'entities', 'author', 'media', 'quoted', 'id'])

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df=pd.DataFrame(data2).T
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/construction.py:680, in _extract_index(data)
#     677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
# --> 680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#     684 if have_series:
#     685     if lengths[0] != len(index):
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.
